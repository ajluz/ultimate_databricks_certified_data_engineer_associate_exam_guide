# %%
# %run "./setup/setup_chapter_05"

# %%
display(spark.sql("""
    SELECT * FROM parquet.`/Volumes/workspace/default/chapter_05/order_details/parquet/`
    """)
)
display(spark.sql("""
    SELECT * FROM parquet.`/Volumes/workspace/default/chapter_05/orders/parquet/`
    """)
)
display(spark.sql("""
    SELECT * FROM parquet.`/Volumes/workspace/default/chapter_05/products/parquet/`
    """)
)
display(spark.sql("""
    SELECT * FROM parquet.`/Volumes/workspace/default/chapter_05/users/parquet/`
    """)
)
